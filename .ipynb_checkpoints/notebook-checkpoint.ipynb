# %% [markdown]
# ## Task 1: YouTube Streamer Analysis

# %% [markdown]
# ### Introduction

# %% [markdown]
# This dataset contains valuable information about the top YouTube streamers,including their ranking, categories, subscribers,country, visits, likes, comments, and more.Your task is to perform a comprehensive analysis of the dataset to extract insightsabout the top YouTube content creators.
# s

# %% [markdown]
# ### Data Understanding

# %% [markdown]
# 1. ranking: Indicates the ranking of the YouTube account.
# 2. username: The account name of the YouTuber or YouTube channel.
# 3. categories: The category or categories that describe the content created by the channel.
# 4. subscribers: Number of subscribers the channel has.
# 5. country: The country from which the YouTuber originates or represents.
# 6. visits: Total number of views amassed by the account.
# 7. likes: Total number of likes received on the account's content.
# 8. comments: Total number of comments posted on the account's content.
# 9. links: A URL or link pointing to the YouTube account or channel.
# hannel.
# channel.hannel.

# %% [markdown]
# ### Dataset : Top 1000 Youtubers statistics

# %%
import pandas as pd
import warnings  
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
df = pd.read_csv('youtubers_df.csv')

# %%
df.head()
# Out:
#         Username          Categories   Suscribers  Country       Visits  \
# 0        tseries     Music and Dance  249500000.0    India      86200.0
# 1        MrBeast  Video Games, Humor  183500000.0      NaN  117400000.0
# 2      CoComelon           Education  165500000.0  Unknown    7000000.0
# 3       SETIndia             Unknown  162600000.0    India      15600.0
# 4  KidsDianaShow     Animation, Toys  113500000.0  Unknown    3900000.0
#
#        Likes  Comments                                              Links
# 0     2700.0      78.0  http://youtube.com/channel/UCq-Fj5jknLsUf-MWSy...
# 1  5300000.0   18500.0  http://youtube.com/channel/UCX6OQ3DkcsbYNE6H8u...
# 2    24700.0       0.0  http://youtube.com/channel/UCbCmjCuTUZos6Inko4...
# 3      166.0       9.0  http://youtube.com/channel/UCpEhnqL0y41EpW2TvW...
# 4    12400.0       0.0  http://youtube.com/channel/UCk8GzjMOrta8yxDcKf...

# %% [markdown]
# ## 1. Data Exploration:

# %%
# Get more information about the columns and their data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Rank        1000 non-null   int64
#  1   Username    1000 non-null   object
#  2   Categories  694 non-null    object
#  3   Suscribers  1000 non-null   float64
#  4   Country     1000 non-null   object
#  5   Visits      1000 non-null   float64
#  6   Likes       1000 non-null   float64
#  7   Comments    1000 non-null   float64
#  8   Links       1000 non-null   object
# dtypes: float64(4), int64(1), object(4)
# memory usage: 70.4+ KB

# %%
# Check the number of columns and rows in each data
df.shape
# Out:
# (1000, 9)

# %% [markdown]
# ## Data Cleaning

# %%
df
# Out:
#      Rank              Username           Categories   Suscribers  \
# 0       1               tseries       Música y baile  249500000.0
# 1       2               MrBeast   Videojuegos, Humor  183500000.0
# 2       3             CoComelon            Educación  165500000.0
# 3       4              SETIndia                  NaN  162600000.0
# 4       5         KidsDianaShow  Animación, Juguetes  113500000.0
# ..    ...                   ...                  ...          ...
# 995   996          hamzymukbang                  NaN   11700000.0
# 996   997            Adaahqueen                  NaN   11700000.0
# 997   998  LittleAngelIndonesia       Música y baile   11700000.0
# 998   999          PenMultiplex                  NaN   11700000.0
# 999  1000         OneindiaHindi  Noticias y Política   11700000.0
#
#             Country       Visits      Likes  Comments  \
# 0             India      86200.0     2700.0      78.0
# 1    Estados Unidos  117400000.0  5300000.0   18500.0
# ...

# %%
# Identify Duplicates
df.duplicated().sum()
# Out:
# 0

# %%
df[df.Links.duplicated(keep=False)]
# Out:
#      Rank        Username                    Categories  Suscribers  \
# 249   250      NickyJamTV     Música y baile, Películas  23700000.0
# 250   251      NickyJamTV     Música y baile, Películas  23700000.0
# 447   448    mgcplayhouse  Juguetes, Coches y vehículos  17800000.0
# 449   450       thexoteam                           NaN  17800000.0
# 450   451       thexoteam                           NaN  17900000.0
# 451   452    mgcplayhouse  Juguetes, Coches y vehículos  17800000.0
# 946   947  Super_Senya_RU           Animación, Juguetes  12100000.0
# 947   948   HiTechIslamic                Música y baile  12100000.0
# 949   950      Family-Box                     Películas  12000000.0
# 952   953  Super_Senya_RU           Animación, Juguetes  12100000.0
# 953   954   HiTechIslamic                Música y baile  12100000.0
# 956   957      Family-Box                     Películas  12000000.0
#
#             Country    Visits    Likes  Comments  \
# ...

# %%
# Drop duplicated columns 
df.Links.drop_duplicates(inplace=True)

# %%
df[df.Links.duplicated()]
# Out:
#      Rank        Username                    Categories  Suscribers  \
# 250   251      NickyJamTV     Música y baile, Películas  23700000.0
# 450   451       thexoteam                           NaN  17900000.0
# 451   452    mgcplayhouse  Juguetes, Coches y vehículos  17800000.0
# 952   953  Super_Senya_RU           Animación, Juguetes  12100000.0
# 953   954   HiTechIslamic                Música y baile  12100000.0
# 956   957      Family-Box                     Películas  12000000.0
#
#             Country    Visits    Likes  Comments  \
# 250        Colombia   15800.0   1200.0      58.0
# 450  Estados Unidos  772800.0  45000.0     185.0
# 451         Unknown   63600.0     75.0       0.0
# 952         Unknown   47200.0    192.0       0.0
# 953        Pakistán   62200.0    810.0      59.0
# 956           Rusia  177400.0   6300.0      86.0
#
#                                                  Links
# 250  http://youtube.com/channel/UCpb_iJuhFe8V6rQdbN...
# ...

# %%
df.drop(axis= 0, index= [450,451,956], inplace = True) 
df[df.Links.duplicated()]
# Out:
#      Rank        Username                 Categories  Suscribers   Country  \
# 250   251      NickyJamTV  Música y baile, Películas  23700000.0  Colombia
# 952   953  Super_Senya_RU        Animación, Juguetes  12100000.0   Unknown
# 953   954   HiTechIslamic             Música y baile  12100000.0  Pakistán
#
#       Visits   Likes  Comments  \
# 250  15800.0  1200.0      58.0
# 952  47200.0   192.0       0.0
# 953  62200.0   810.0      59.0
#
#                                                  Links
# 250  http://youtube.com/channel/UCpb_iJuhFe8V6rQdbN...
# 952  http://youtube.com/channel/UCTn9Vyy-3fzLIr0bqh...
# 953  http://youtube.com/channel/UCtKKyuORzErSd7TWfk...

# %%
# Reset the index of the data frame 
df.reset_index(drop=True, inplace=True,)

# %%
# check for missing values
df.isnull().sum()
# Out:
# Rank            0
# Username        0
# Categories    305
# Suscribers      0
# Country         0
# Visits          0
# Likes           0
# Comments        0
# Links           0
# dtype: int64

# %%
df.Categories.value_counts()
# Out:
# Categories
# Música y baile                        160
# Películas, Animación                   61
# Música y baile, Películas              41
# Vlogs diarios                          37
# Noticias y Política                    36
# Películas, Humor                       34
# Animación, Videojuegos                 34
# Animación, Juguetes                    29
# Animación, Humor                       27
# Educación                              24
# Películas                              23
# Animación                              22
# Videojuegos                            19
# Videojuegos, Humor                     17
# Música y baile, Animación              16
# Ciencia y tecnología                   14
# Comida y bebida                        12
# Humor                                  10
# Juguetes                               10
# Películas, Juguetes                     9
# Películas, Videojuegos                  8
# Deportes                                8
# ...

# %%
print(df['Categories'])
# Out:
# 0           Música y baile
# 1       Videojuegos, Humor
# 2                Educación
# 3                      NaN
# 4      Animación, Juguetes
#               ...
# 992                    NaN
# 993                    NaN
# 994         Música y baile
# 995                    NaN
# 996    Noticias y Política
# Name: Categories, Length: 997, dtype: object

# %%
# Assuming 'df' is your DataFrame
unique_categories = df['Categories'].unique()
print(unique_categories)
# Out:
# ['Música y baile' 'Videojuegos, Humor' 'Educación' nan
#  'Animación, Juguetes' 'Películas, Videojuegos' 'Juguetes' 'Videojuegos'
#  'Películas, Animación' 'Películas' 'Noticias y Política'
#  'Animación, Humor' 'Música y baile, Animación'
#  'Música y baile, Películas' 'Películas, Juguetes' 'Películas, Humor'
#  'Vlogs diarios' 'Videojuegos, Juguetes' 'Animación, Videojuegos'
#  'Animación' 'Música y baile, Humor' 'Diseño/arte, DIY y Life Hacks'
#  'Ciencia y tecnología' 'Fitness, Salud y autoayuda' 'Belleza, Moda'
#  'Humor' 'Comida y bebida' 'Deportes' 'Fitness' 'Viajes, Espectáculos'
#  'Comida y bebida, Salud y autoayuda' 'Diseño/arte'
#  'DIY y Life Hacks, Juguetes' 'Educación, Juguetes'
#  'Juguetes, Coches y vehículos' 'Música y baile, Juguetes'
#  'Animales y mascotas' 'ASMR' 'Moda' 'DIY y Life Hacks'
#  'Diseño/arte, Belleza' 'Coches y vehículos' 'Animación, Humor, Juguetes'
#  'ASMR, Comida y bebida' 'Comida y bebida, Juguetes'
#  'Juguetes, DIY y Life Hacks']

# %% [markdown]
# converting Spanish to English in Categories colmun

# %%
translation_dict = {'Música y baile': 'Music and Dance',     
                    'Videojuegos, Humor': 'Video Games, Humor',     
                    'Educación': 'Education',     
                    'Unknown': 'Unknown',     
                    'Animación, Juguetes': 'Animation, Toys',     
                    'Películas, Videojuegos': 'Movies, Video Games',     
                    'Juguetes': 'Toys',     'Videojuegos': 'Video Games',     
                    'Películas, Animación': 'Movies, Animation',     
                    'Películas': 'Movies','Noticias y Política': 'News and Politics',     
                    'Animación, Humor': 'Animation, Humor',     
                    'Música y baile, Animación': 'Music and Dance, Animation',     
                    'Música y baile, Películas': 'Music and Dance, Movies',     
                    'Películas, Juguetes': 'Movies, Toys',     
                    'Películas, Humor': 'Movies, Humor',     
                    'Vlogs diarios': 'Daily Vlogs',     
                    'Videojuegos, Juguetes': 'Video Games, Toys',     
                    'Animación, Videojuegos': 'Animation, Video Games',     
                    'Animación': 'Animation','Música y baile, Humor': 'Music and Dance, Humor',     
                    'Diseño/arte, DIY y Life Hacks': 'Design/Art, DIY and Life Hacks',     
                    'Ciencia y tecnología': 'Science and Technology',     
                    'Fitness, Salud y autoayuda': 'Fitness, Health and Self-help',     
                    'Belleza, Moda': 'Beauty, Fashion', 'Humor': 'Humor',     
                    'Comida y bebida': 'Food and Drink',     
                    'Deportes': 'Sports','Fitness': 'Fitness',     
                    'Viajes, Espectáculos': 'Travel, Entertainment',     
                    'Comida y bebida, Salud y autoayuda':'Food and Drink, Health and Self-help',     
                    'Diseño/arte': 'Design/Art','DIY y Life Hacks, Juguetes': 'DIY and Life Hacks, Toys',     
                    'Educación, Juguetes': 'Education, Toys',     
                    'Juguetes, Coches y vehículos': 'Toys, Cars and Vehicles',     
                    'Música y baile, Juguetes': 'Music and Dance, Toys',     
                    'Animales y mascotas': 'Animals and Pets', 'ASMR': 'ASMR',     
                    'Moda': 'Fashion',     'DIY y Life Hacks': 'DIY and Life Hacks',     
                    'Diseño/arte, Belleza': 'Design/Art, Beauty', 'Coches y vehículos': 'Cars and Vehicles',     
                    'Animación, Humor, Juguetes': 'Animation, Humor, Toys', 'ASMR, Comida y bebida': 'ASMR, Food and Drink',     
                    'Comida y bebida, Juguetes': 'Food and Drink, Toys', 'Juguetes, DIY y Life Hacks': 'Toys, DIY and Life Hacks' }  
# Function to translate Spanish words to English 
def translate_to_english(word):    
    return translation_dict.get(word, word)  # Return the translated word if it exists,  
# Apply the translation function to the 'Category' column 
df['Categories'] = df['Categories'].apply(translate_to_english)

# %%
df
# Out:
#      Rank              Username          Categories   Suscribers  \
# 0       1               tseries     Music and Dance  249500000.0
# 1       2               MrBeast  Video Games, Humor  183500000.0
# 2       3             CoComelon           Education  165500000.0
# 3       4              SETIndia                 NaN  162600000.0
# 4       5         KidsDianaShow     Animation, Toys  113500000.0
# ..    ...                   ...                 ...          ...
# 992   996          hamzymukbang                 NaN   11700000.0
# 993   997            Adaahqueen                 NaN   11700000.0
# 994   998  LittleAngelIndonesia     Music and Dance   11700000.0
# 995   999          PenMultiplex                 NaN   11700000.0
# 996  1000         OneindiaHindi   News and Politics   11700000.0
#
#             Country       Visits      Likes  Comments  \
# 0             India      86200.0     2700.0      78.0
# 1    Estados Unidos  117400000.0  5300000.0   18500.0
# ...

# %% [markdown]
# converting Spanish to English in Country colmun

# %%
unique_country = df['Country'].unique()
print(unique_country)
# Out:
# ['India' 'Estados Unidos' 'Unknown' 'Brasil' 'México' 'Rusia' 'Pakistán'
#  'Filipinas' 'Indonesia' 'Tailandia' 'Francia' 'Colombia' 'Iraq' 'Japón'
#  'Ecuador' 'Argentina' 'Turquía' 'Arabia Saudita' 'El Salvador'
#  'Bangladesh' 'Reino Unido' 'Argelia' 'España' 'Perú' 'Egipto' 'Jordania'
#  'Marruecos' 'Singapur' 'Somalia']

# %%
# Mapping of Spanish to English countries
spanish_countries = [
    'India', 'Estados Unidos', 'Unknown', 'Brasil', 'México', 'Rusia', 'Pakistán',
    'Filipinas', 'Indonesia', 'Tailandia', 'Francia', 'Colombia', 'Iraq', 'Japón',
    'Ecuador', 'Argentina', 'Turquía', 'Arabia Saudita', 'El Salvador',
    'Bangladesh', 'Reino Unido', 'Argelia', 'España', 'Perú', 'Egipto', 'Jordania',
    'Marruecos', 'Singapur', 'Somalia'
]

english_countries = [
    'India', 'United States', 'Unknown', 'Brazil', 'Mexico', 'Russia', 'Pakistan',
    'Philippines', 'Indonesia', 'Thailand', 'France', 'Colombia', 'Iraq', 'Japan',
    'Ecuador', 'Argentina', 'Turkey', 'Saudi Arabia', 'El Salvador',
    'Bangladesh', 'United Kingdom', 'Algeria', 'Spain', 'Peru', 'Egypt', 'Jordan',
    'Morocco', 'Singapore', 'Somalia'
]

# Create a dictionary mapping Spanish countries to English countries
spanish_to_english_countries = dict(zip(spanish_countries, english_countries))

# Replace countries in the DataFrame
df['Country'] = df['Country'].map(spanish_to_english_countries)

# %%
df
# Out:
#      Rank              Username          Categories   Suscribers  \
# 0       1               tseries     Music and Dance  249500000.0
# 1       2               MrBeast  Video Games, Humor  183500000.0
# 2       3             CoComelon           Education  165500000.0
# 3       4              SETIndia                 NaN  162600000.0
# 4       5         KidsDianaShow     Animation, Toys  113500000.0
# ..    ...                   ...                 ...          ...
# 992   996          hamzymukbang                 NaN   11700000.0
# 993   997            Adaahqueen                 NaN   11700000.0
# 994   998  LittleAngelIndonesia     Music and Dance   11700000.0
# 995   999          PenMultiplex                 NaN   11700000.0
# 996  1000         OneindiaHindi   News and Politics   11700000.0
#
#             Country       Visits      Likes  Comments  \
# 0             India      86200.0     2700.0      78.0
# 1    Estados Unidos  117400000.0  5300000.0   18500.0
# ...

# %%
# check for missing values
df.isnull().sum()
# Out:
# Rank            0
# Username        0
# Categories    305
# Suscribers      0
# Country         0
# Visits          0
# Likes           0
# Comments        0
# Links           0
# dtype: int64

# %%
# Replace empty cells in category with 'Unknown' 
df.Categories.fillna(value='Unknown', inplace= True)

# %%
df.describe()
# Out:
#               Rank    Suscribers        Visits         Likes       Comments
# count   997.000000  9.970000e+02  9.970000e+02  9.970000e+02     997.000000
# mean    500.140421  2.191244e+07  1.212069e+06  5.374244e+04    1292.374122
# std     288.883612  1.684918e+07  5.237566e+06  2.584239e+05    6788.067878
# min       1.000000  1.170000e+07  0.000000e+00  0.000000e+00       0.000000
# 25%     250.000000  1.380000e+07  3.190000e+04  4.720000e+02       2.000000
# 50%     501.000000  1.670000e+07  1.744000e+05  3.500000e+03      67.000000
# 75%     750.000000  2.370000e+07  8.678000e+05  2.850000e+04     472.000000
# max    1000.000000  2.495000e+08  1.174000e+08  5.300000e+06  154000.000000

# %% [markdown]
# ## 2. Trend Analysis:

# %% [markdown]
# Identify trends among the top YouTube streamers. Which categories are the most popular?
#  Is there a correlation between the number of subscribers and the number of likes or comments?

# %%
# Selecting only numeric columns for correlation calculation
numeric_df = df.select_dtypes(include=['float64', 'int64'])

# Calculate correlation matrix
correlation_matrix = numeric_df.corr()

# Create a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ## Observations
#
# Interestingly, there's no evident correlation between the number of subscribers and likes, nor between subscribers and comments. The "Rank" column shows no meaningful correlation with any other column in the dataset, offering no valuable insights and is hence recommended for removal. However, a notable strong correlation exists between the number of visits and likes. There seems to be a weaker linear relationship between visits and comments, as well as between likes and comments. Additionally, there's no apparent correlation between the number of comments and the count of subscribers.

# %%
# Dropping `Rank` from the dataframe 
df.drop(axis=1, columns='Rank', inplace= True)

# %%
df.hist();

# %% [markdown]
# The histogram indicates a substantial presence of outliers within this dataset. This is quite expected, considering the broad spectrum in which counts of subscribers, likes, and comments can vary within the realm of content creation.

# %% [markdown]
# ## 3. Audience Study:

# %% [markdown]
# Analyze the distribution of streamers' audiences by country. Are there regional preferences for
# specific content categories?

# %%
# Group data by 'Country' and 'Categories', aggregating audience metrics
audience_by_country_category = df.groupby(['Country', 'Categories'])['Suscribers'].sum().unstack().fillna(0)

# Plotting the horizontal bar chart
plt.figure(figsize=(12, 8))
audience_by_country_category.plot(kind='barh', stacked=True, cmap='viridis')
plt.title('Subscribers by Content Category and Country')
plt.xlabel('Subscribers')
plt.ylabel('Countries')
plt.legend(title='Categories', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
streamers_by_category = df['Categories'].value_counts().head(10)
# Now, you can proceed to plot the pie chart
plt.figure(figsize=(8, 8))
streamers_by_category.plot(kind='pie', autopct='%1.1f%%', cmap='Set3')
plt.title('Top 10 Streamers Distribution by Category')
plt.ylabel('')
plt.show()

# %%
# Creating the cross-tabulation
cross_tab = pd.crosstab(df['Country'], df['Categories'])

# Displaying the cross-tabulation
cross_tab
# Out:
# Categories   Animation  Animation, Humor  Animation, Toys  \
# Country
# Argentina            1                 0                0
# Bangladesh           0                 0                0
# Colombia             0                 2                0
# Ecuador              0                 0                0
# El Salvador          0                 0                0
# India                0                 0                0
# Indonesia            0                 0                0
# Iraq                 0                 0                0
# Somalia              0                 0                0
# Unknown              8                 3               28
#
# Categories   Animation, Video Games  Daily Vlogs  Education  Education, Toys  \
# Country
# Argentina                         0            0          0                0
# Bangladesh                        0            1          0                0
# ...

# %% [markdown]
# - Calculate and visualize the average number of subscribers, visits, likes, and comments.
# - Are there patterns or anomalies in these metrics?

# %%
# Calculate average values for subscribers, visits, likes, and comments
average_values = df[['Suscribers', 'Visits', 'Likes', 'Comments']].mean()

print("Average Number of:")
print(f"Subscribers: {average_values['Suscribers']:.2f}")
print(f"Visits: {average_values['Visits']:.2f}")
print(f"Likes: {average_values['Likes']:.2f}")
print(f"Comments: {average_values['Comments']:.2f}")
# Out:
# Average Number of:
# Subscribers: 21912437.31
# Visits: 1212068.72
# Likes: 53742.44
# Comments: 1292.37

# %%
# Adjusting the visual style for the bar chart
plt.figure(figsize=(10, 6))
average_values.plot(kind='bar', color=['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728'])
plt.title('Average Subscribers, Visits, Likes, and Comments')
plt.xlabel('Metrics')
plt.ylabel('Average Value')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Descriptive statistics for subscribers, visits, likes, and comments
metrics_summary = df[['Suscribers', 'Visits', 'Likes', 'Comments']].describe()
print(metrics_summary)
# Out:
#          Suscribers        Visits         Likes       Comments
# count  9.970000e+02  9.970000e+02  9.970000e+02     997.000000
# mean   2.191244e+07  1.212069e+06  5.374244e+04    1292.374122
# std    1.684918e+07  5.237566e+06  2.584239e+05    6788.067878
# min    1.170000e+07  0.000000e+00  0.000000e+00       0.000000
# 25%    1.380000e+07  3.190000e+04  4.720000e+02       2.000000
# 50%    1.670000e+07  1.744000e+05  3.500000e+03      67.000000
# 75%    2.370000e+07  8.678000e+05  2.850000e+04     472.000000
# max    2.495000e+08  1.174000e+08  5.300000e+06  154000.000000

# %%
# Boxplot to visualize distribution and outliers
plt.figure(figsize=(12, 6))
df[['Suscribers', 'Visits', 'Likes', 'Comments']].boxplot()
plt.title('Boxplot for Subscribers, Visits, Likes, and Comments')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Content Categories:

# %% [markdown]
# - Explore the distribution of content categories. Which categories have the highest number of
# streamers?
# - Are there specific categories with exceptional performance metrics?

# %%
# Count occurrences of streamers per content category
category_counts = df['Categories'].value_counts()

# Display top categories by the number of streamers
print("Top Categories by Number of Streamers:")
print(category_counts.head(10))  # Display top 10 categories

# Visualize the distribution of streamers across categories using a horizontal bar chart
plt.figure(figsize=(10, 8))
category_counts.head(20).sort_values().plot(kind='barh', color='salmon')
plt.title('Top Categories by Number of Streamers')
plt.xlabel('Number of Streamers')
plt.ylabel('Categories')
plt.tight_layout()
plt.show()
# Out:
# Top Categories by Number of Streamers:
# Categories
# Unknown                    305
# Music and Dance            160
# Movies, Animation           61
# Music and Dance, Movies     41
# Daily Vlogs                 37
# News and Politics           36
# Movies, Humor               34
# Animation, Video Games      34
# Animation, Toys             29
# Animation, Humor            27
# Name: count, dtype: int64

# %%
# Calculate mean values for subscribers, visits, likes, and comments per category
category_metrics = df.groupby('Categories')[['Suscribers', 'Visits', 'Likes', 'Comments']].mean()

# Display top categories by subscribers (for example)
top_categories_subscribers = category_metrics['Suscribers'].nlargest(5)
print("Top Categories by Average Subscribers:")
print(top_categories_subscribers)

# Display top categories by visits, likes, or comments (adjust metric as needed)
# top_categories_visits = category_metrics['Visits'].nlargest(5)
# top_categories_likes = category_metrics['Likes'].nlargest(5)
# top_categories_comments = category_metrics['Comments'].nlargest(5)
# Out:
# Top Categories by Average Subscribers:
# Categories
# Toys                   3.788000e+07
# Movies, Video Games    3.325000e+07
# Animation, Toys        2.937586e+07
# Video Games, Humor     2.876471e+07
# Music and Dance        2.683688e+07
# Name: Suscribers, dtype: float64

# %%
# Calculate mean values for subscribers, visits, likes, and comments per category
category_metrics = df.groupby('Categories')[['Suscribers', 'Visits', 'Likes', 'Comments']].mean()

# Display top categories by subscribers
top_categories_subscribers = category_metrics['Suscribers'].nlargest(5)

# Visualize top categories by average subscribers using a bar chart
plt.figure(figsize=(10, 6))
top_categories_subscribers.plot(kind='bar', color='skyblue')
plt.title('Top Categories by Average Subscribers')
plt.xlabel('Categories')
plt.ylabel('Average Subscribers')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. Brands and Collaborations:

# %% [markdown]
# Analyze whether streamers with high performance metrics receive more brand collaborations and
# marketing campaigns.

# %% [markdown]
# Data on brand collaboration and marketing campaigns was not provided.

# %% [markdown]
# ## 7. Benchmarking:

# %% [markdown]
# - Identify streamers with above-average performance in terms of subscribers, visits, likes, and comments.
# - Who are the top-performing content creators?

# %%
# Calculate average performance metrics
average_metrics = df[['Suscribers', 'Visits', 'Likes', 'Comments']].mean()

# %%
# Identify streamers with above-average performance
above_average_streamers = df[
    (df['Suscribers'] > average_metrics['Suscribers']) &
    (df['Visits'] > average_metrics['Visits']) &
    (df['Likes'] > average_metrics['Likes']) &
    (df['Comments'] > average_metrics['Comments'])
]

# %%
# Find top-performing content creators (e.g., top 10 based on subscribers)
top_performers = df.nlargest(10, 'Suscribers')

# %%
# Display above-average streamers and top-performing content creators
print("Streamers with Above-Average Performance:")
print(above_average_streamers[['Username', 'Suscribers', 'Visits', 'Likes', 'Comments']])

print("\nTop-Performing Content Creators:")
print(top_performers[['Username', 'Suscribers', 'Visits', 'Likes', 'Comments']])
# Out:
# Streamers with Above-Average Performance:
#                   Username   Suscribers       Visits      Likes  Comments
# 1                  MrBeast  183500000.0  117400000.0  5300000.0   18500.0
# 5                PewDiePie  111500000.0    2400000.0   197300.0    4900.0
# 26             dudeperfect   59700000.0    5300000.0   156500.0    4200.0
# 34             TaylorSwift   54100000.0    4300000.0   300400.0   15000.0
# 39             JuegaGerman   48600000.0    2000000.0   117100.0    3000.0
# 43                A4a4a4a4   47300000.0    9700000.0   330400.0   22000.0
# 58               Mikecrack   43400000.0    2200000.0   183400.0    1800.0
# 62          KimberlyLoaiza   42100000.0    5300000.0   271300.0   16000.0
# 64         luisitocomunica   41100000.0    2500000.0   128900.0    1800.0
# 70             JessNoLimit   39600000.0    1300000.0    73500.0    1600.0
# 96          TotalGaming093   36300000.0    1500000.0   129400.0    4900.0
# ...

# %% [markdown]
# ## 8. Content Recommendations:

# %% [markdown]
# - Propose a system for enhancing content recommendations to YouTube users based on streamers'
# - categories and performance metrics.

# %%
# Step 1: User preferences (simulated)
user_preferences = {'Categories': ['Music and Dance', 'Video Games'], 'Suscribers': 1000000, 'Visits': 50000}

# Step 2: Filtering based on user preferences
filtered_streamers = df[
    (df['Categories'].isin(user_preferences['Categories'])) &
    (df['Suscribers'] >= user_preferences['Suscribers']) &
    (df['Visits'] >= user_preferences['Visits'])
]

# Step 3: Sort and recommend top streamers
recommended_streamers = filtered_streamers.sort_values(by=['Suscribers', 'Visits', 'Likes', 'Comments'], ascending=False).head(10)

# Display recommended streamers
print("Recommended Streamers:")
print(recommended_streamers[['Username', 'Categories', 'Suscribers', 'Visits', 'Likes', 'Comments']])
# Out:
# Recommended Streamers:
#            Username       Categories   Suscribers     Visits     Likes  \
# 0           tseries  Music and Dance  249500000.0    86200.0    2700.0
# 8   zeemusiccompany  Music and Dance   99700000.0    74300.0    2600.0
# 9               WWE      Video Games   97200000.0   184500.0    6300.0
# 10        BLACKPINK  Music and Dance   91300000.0   863200.0  146900.0
# 14              BTS  Music and Dance   76500000.0   969700.0  180300.0
# 15       HYBELABELS  Music and Dance   72700000.0   440700.0   23900.0
# 23     tipsofficial  Music and Dance   60900000.0    80200.0     935.0
# 26      dudeperfect      Video Games   59700000.0  5300000.0  156500.0
# 25  ElReinoInfantil  Music and Dance   59700000.0   393000.0    2600.0
# 30       marshmello  Music and Dance   56700000.0   145900.0    8900.0
#
#     Comments
# 0       78.0
# 8       32.0
# 9      214.0
# 10    3400.0
# 14    7400.0
# 15     932.0
# 23      22.0
# 26    4200.0
# 25       0.0
# 30     167.0
